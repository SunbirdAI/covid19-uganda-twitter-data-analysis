# %% [markdown]
# ## Twitter Data Collection Documentation
# The goal of this notebook is to document the way in which we're currently collecting data from the twitter API. This includes challenges faced in the collection, rationale behind the current method and the overall goals of the project.
#
# ### What's the project about?
# The aim of the project is to analyse daily public social media discussion in Uganda relating to the COVID-19 pandemic to inform decision making by the National Task Force ([reference](https://docs.google.com/document/d/1a8JI6GS67B6ot4fE1mMbIs0jmnagckw8meoATGM6iNI/edit?usp=sharing)).
#
# We also hope to use the data collected from twitter (along with data from other data sources) for building a language model on use of language in Uganda.
#
# ### Collecting data from Twitter
# Twitter provides a number of ways of retrieving tweets based on a variety of criteria such as hashtags, keywords, trending topics, location, user handles, dates e.t.c
#
# We've been using the [Standard Search API](https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets) which returns a collection of relevant Tweets matching a specified query. The query can contain hashtags, user accounts and keywords. An example of a query string is: `q='from:MinofHealthUG OR to:MinOfHealthUG OR #covid19'`; this means return tweets that are either from the user handle `MinofHealthUG` or replies to the handle `MinofHealthUG` or containing the hashtag `#covid19`.
#
# We've also been leveraging [Python Twitter Tools](https://github.com/sixohsix/twitter) in order to make requests to the API easier.
#
# Ways of collecting data that we've considered/used are the following:
#
# #### Retrieve tweets based on key user accounts, relevant hashtags.
# An example of this is when we analysed masks tweets following the presidential address (code can be found [here](https://github.com/SunbirdAI/covid19-uganda-twitter-data-analysis/blob/master/MaskRelatedData.py)).
#
# Advantages of this approach:
# - We can get very specific tweets about the subject/people in question.
#
# Disadvantages:
# - Using a predefined list of user accounts and hashtags limits the tweets retrieved to those mentioning that particular hashtag and tweets from popular accounts.
# - As time goes on, a particular topic is discussed less and less and people move on to new things; this means that the new tweets about that topic get fewer and fewer. This limits the number of tweets we can collect if the goal is to collect tweets daily.
#
# A potential mitigation for the limited tweets we get is to get replies to the initial tweets we collect; this was tried during the "masks tweets" analysis but the replies were very few in number.
#
# #### Retrieve tweets based on an initial list of users and then dynamically increase the user-pool based on replies to those users.
# This is the method currently being used for the continuous data collection. It involves using an initial list of popular users (based on follower count) and after collecting some tweets from (and replies to) the user, it adds new users that appear in the latest tweets to the users list. For each subsequent request, a random sample of 15 users is chosen from the list and the process repeated.
#
# For details about this, refer to the code, which is as follows:
# - [Data collection script](https://github.com/SunbirdAI/covid19-uganda-twitter-data-analysis/blob/master/run_twitter_data_script.py): This script contains the code (with comments for each function) that implements the data collection strategy described above.
# - [Data collection package](https://github.com/SunbirdAI/covid19-uganda-twitter-data-analysis/tree/master/data_collection): Contains the files `db_utils.py` (which is used for interfacing with `mongodb`) and `twitter_api_utils.py` (which is used for interfacing with the Twitter API). All methods in these files have docstrings which explain what each of them does.
#
# Advantages
# - Diverse tweets from many different users. This diversity could aid in building the language model mentioned at the start of this document.
# - In addition, when searching the data for specific topics/issues of interest, having very many different tweets may give us an idea of how frequently that particular topic is being discussed along with the context in which it was being discussed (for example by looking at popular hashtags on a particular day).
#
# Disadvantages
# - Replies to accounts may not be from Ugandan users, so a significant number of tweets may not be relevant to the Ugandan context on which this project is based. (Issues with location are discussed further later in this document)
# - Because the tweets are retrieved randomly, there is no guarantee that topics of interest will appear (frequently enough) in the collected tweets.
#
# #### Retrieve tweets based on location (or trending topics in a location)
# This would probably be the best solution to our data collection problems because we could use this to keep track topics trending each day, we would also be sure that the tweets are coming from people in Uganda and the tweets would still be sufficiently diverse as to aid buidling a language model.
#
# The following code illustrates the problems I ran into while pursuing this approach.

# %%
# Setup
import twitter
import os
import json
from dotenv import load_dotenv
load_dotenv()

# Authentication
API_KEY = os.getenv("TWITTER_API_KEY")
API_SECRET = os.getenv("TWITTER_API_SECRET")

auth = twitter.oauth.OAuth("", "", API_KEY, API_SECRET)

twitter_api = twitter.Twitter(auth=auth)

# %% [markdown]
# - Getting [trends near a location](https://developer.twitter.com/en/docs/trends/trends-for-location/api-reference/get-trends-place) using the location's [WOEID](https://en.wikipedia.org/wiki/WOEID) (currently managed by Yahoo)
# - The following WOEIDs were retrieved from this site: https://www.findmecity.com/.
# - I also tried using [this method](https://stackoverflow.com/questions/22927307/how-to-find-woeid-where-on-earth-id-of-a-country) on stackoverflow, but it seems like the `yweather` python package is no longer supported and the Yahoo weather API was deprecated.

# %%
WORLD_WOEID = 1
US_WOEID = 23424977
UG_WOEID = 23424974
KLA_WOEID = 1451962
KENYA_WOEID = 23424863

# %%
# We can get world trends without a problem
world_trends = twitter_api.trends.place(_id=WORLD_WOEID)
print(json.dumps(world_trends, indent=1))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#pinargultekin",
#     "url": "http://twitter.com/search?q=%23pinargultekin",
#     "promoted_content": null,
#     "query": "%23pinargultekin",
#     "tweet_volume": 676624
#    },
#    {
#     "name": "#P\u0131nar\u0131nkatiliCHPli",
#     "url": "http://twitter.com/search?q=%23P%C4%B1nar%C4%B1nkatiliCHPli",
#     "promoted_content": null,
#     "query": "%23P%C4%B1nar%C4%B1nkatiliCHPli",
#     "tweet_volume": 25560
#    },
#    {
#     "name": "#istanbulsozlesmesiyasatir",
#     "url": "http://twitter.com/search?q=%23istanbulsozlesmesiyasatir",
#     "promoted_content": null,
#     "query": "%23istanbulsozlesmesiyasatir",
#     "tweet_volume": 16079
#    },
#    {
#     "name": "#\u79c1\u306e\u5bb6\u653f\u592b\u30ca\u30ae\u30b5\u3055\u3093",
#     "url": "http://twitter.com/search?q=%23%E7%A7%81%E3%81%AE%E5%AE%B6%E6%94%BF%E5%A4%AB%E3%83%8A%E3%82%AE%E3%82%B5%E3%81%95%E3%82%93",
#     "promoted_content": null,
#     "query": "%23%E7%A7%81%E3%81%AE%E5%AE%B6%E6%94%BF%E5%A4%AB%E3%83%8A%E3%82%AE%E3%82%B5%E3%81%95%E3%82%93",
#     "tweet_volume": 10635
#    },
#    {
#     "name": "#DiaMundialDelPerro",
#     "url": "http://twitter.com/search?q=%23DiaMundialDelPerro",
#     "promoted_content": null,
#     "query": "%23DiaMundialDelPerro",
#     "tweet_volume": 12367
#    },
#    {
#     "name": "\u571f\u7528\u306e\u4e11\u306e\u65e5",
#     "url": "http://twitter.com/search?q=%E5%9C%9F%E7%94%A8%E3%81%AE%E4%B8%91%E3%81%AE%E6%97%A5",
#     "promoted_content": null,
#     "query": "%E5%9C%9F%E7%94%A8%E3%81%AE%E4%B8%91%E3%81%AE%E6%97%A5",
#     "tweet_volume": 171138
#    },
#    {
#     "name": "\u30d5\u30a7\u30b9",
#     "url": "http://twitter.com/search?q=%E3%83%95%E3%82%A7%E3%82%B9",
#     "promoted_content": null,
#     "query": "%E3%83%95%E3%82%A7%E3%82%B9",
#     "tweet_volume": 69536
#    },
#    {
#     "name": "ANY GABRIELLY NO ENCONTRO",
#     "url": "http://twitter.com/search?q=%22ANY+GABRIELLY+NO+ENCONTRO%22",
#     "promoted_content": null,
#     "query": "%22ANY+GABRIELLY+NO+ENCONTRO%22",
#     "tweet_volume": 65998
#    },
#    {
#     "name": "\u5acc\u304c\u3089\u305b\u5f01\u5f53",
#     "url": "http://twitter.com/search?q=%E5%AB%8C%E3%81%8C%E3%82%89%E3%81%9B%E5%BC%81%E5%BD%93",
#     "promoted_content": null,
#     "query": "%E5%AB%8C%E3%81%8C%E3%82%89%E3%81%9B%E5%BC%81%E5%BD%93",
#     "tweet_volume": null
#    },
#    {
#     "name": "\u6a2a\u6d5c\u6d41\u661f",
#     "url": "http://twitter.com/search?q=%E6%A8%AA%E6%B5%9C%E6%B5%81%E6%98%9F",
#     "promoted_content": null,
#     "query": "%E6%A8%AA%E6%B5%9C%E6%B5%81%E6%98%9F",
#     "tweet_volume": 72584
#    },
#    {
#     "name": "\u3059\u308f\u307b\u30fc",
#     "url": "http://twitter.com/search?q=%E3%81%99%E3%82%8F%E3%81%BB%E3%83%BC",
#     "promoted_content": null,
#     "query": "%E3%81%99%E3%82%8F%E3%81%BB%E3%83%BC",
#     "tweet_volume": null
#    },
#    {
#     "name": "\u4e0d\u8981\u4e0d\u6025\u306e\u5916\u51fa\u81ea\u7c9b",
#     "url": "http://twitter.com/search?q=%E4%B8%8D%E8%A6%81%E4%B8%8D%E6%80%A5%E3%81%AE%E5%A4%96%E5%87%BA%E8%87%AA%E7%B2%9B",
#     "promoted_content": null,
#     "query": "%E4%B8%8D%E8%A6%81%E4%B8%8D%E6%80%A5%E3%81%AE%E5%A4%96%E5%87%BA%E8%87%AA%E7%B2%9B",
#     "tweet_volume": 21415
#    },
#    {
#     "name": "\u30d3\u30b7\u30a8\u30c9",
#     "url": "http://twitter.com/search?q=%E3%83%93%E3%82%B7%E3%82%A8%E3%83%89",
#     "promoted_content": null,
#     "query": "%E3%83%93%E3%82%B7%E3%82%A8%E3%83%89",
#     "tweet_volume": 14426
#    },
#    {
#     "name": "\ucd5c\uc560\uc640 \ub2f9\uc2e0\uc758 \uacf5\ud1b5\uc810",
#     "url": "http://twitter.com/search?q=%22%EC%B5%9C%EC%95%A0%EC%99%80+%EB%8B%B9%EC%8B%A0%EC%9D%98+%EA%B3%B5%ED%86%B5%EC%A0%90%22",
#     "promoted_content": null,
#     "query": "%22%EC%B5%9C%EC%95%A0%EC%99%80+%EB%8B%B9%EC%8B%A0%EC%9D%98+%EA%B3%B5%ED%86%B5%EC%A0%90%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "\u6d41\u661f\u304f\u3093",
#     "url": "http://twitter.com/search?q=%E6%B5%81%E6%98%9F%E3%81%8F%E3%82%93",
#     "promoted_content": null,
#     "query": "%E6%B5%81%E6%98%9F%E3%81%8F%E3%82%93",
#     "tweet_volume": 23623
#    },
#    {
#     "name": "\u308c\u304a\u307b\u30fc",
#     "url": "http://twitter.com/search?q=%E3%82%8C%E3%81%8A%E3%81%BB%E3%83%BC",
#     "promoted_content": null,
#     "query": "%E3%82%8C%E3%81%8A%E3%81%BB%E3%83%BC",
#     "tweet_volume": null
#    },
#    {
#     "name": "#BBNajia",
#     "url": "http://twitter.com/search?q=%23BBNajia",
#     "promoted_content": null,
#     "query": "%23BBNajia",
#     "tweet_volume": 51986
#    },
#    {
#     "name": "#FelizMartes",
#     "url": "http://twitter.com/search?q=%23FelizMartes",
#     "promoted_content": null,
#     "query": "%23FelizMartes",
#     "tweet_volume": 18629
#    },
#    {
#     "name": "#BringBackMatiullah",
#     "url": "http://twitter.com/search?q=%23BringBackMatiullah",
#     "promoted_content": null,
#     "query": "%23BringBackMatiullah",
#     "tweet_volume": 61106
#    },
#    {
#     "name": "#Kad\u0131nCinayetleriPolitiktir",
#     "url": "http://twitter.com/search?q=%23Kad%C4%B1nCinayetleriPolitiktir",
#     "promoted_content": null,
#     "query": "%23Kad%C4%B1nCinayetleriPolitiktir",
#     "tweet_volume": 26872
#    },
#    {
#     "name": "#tuesdayvibes",
#     "url": "http://twitter.com/search?q=%23tuesdayvibes",
#     "promoted_content": null,
#     "query": "%23tuesdayvibes",
#     "tweet_volume": 31202
#    },
#    {
#     "name": "#\u30de\u30c4\u30b3\u306e\u77e5\u3089\u306a\u3044\u4e16\u754c",
#     "url": "http://twitter.com/search?q=%23%E3%83%9E%E3%83%84%E3%82%B3%E3%81%AE%E7%9F%A5%E3%82%89%E3%81%AA%E3%81%84%E4%B8%96%E7%95%8C",
#     "promoted_content": null,
#     "query": "%23%E3%83%9E%E3%83%84%E3%82%B3%E3%81%AE%E7%9F%A5%E3%82%89%E3%81%AA%E3%81%84%E4%B8%96%E7%95%8C",
#     "tweet_volume": 11495
#    },
#    {
#     "name": "#\u0648\u0634_\u0627\u0633\u0645_\u062d\u0628\u064a\u0628\u0643",
#     "url": "http://twitter.com/search?q=%23%D9%88%D8%B4_%D8%A7%D8%B3%D9%85_%D8%AD%D8%A8%D9%8A%D8%A8%D9%83",
#     "promoted_content": null,
#     "query": "%23%D9%88%D8%B4_%D8%A7%D8%B3%D9%85_%D8%AD%D8%A8%D9%8A%D8%A8%D9%83",
#     "tweet_volume": 18505
#    },
#    {
#     "name": "#AskElijah",
#     "url": "http://twitter.com/search?q=%23AskElijah",
#     "promoted_content": null,
#     "query": "%23AskElijah",
#     "tweet_volume": 16740
#    },
#    {
#     "name": "#\u092e\u094b\u0926\u0940_\u0915\u093e_\u0930\u093e\u092e\u0930\u093e\u091c\u094d\u092f",
#     "url": "http://twitter.com/search?q=%23%E0%A4%AE%E0%A5%8B%E0%A4%A6%E0%A5%80_%E0%A4%95%E0%A4%BE_%E0%A4%B0%E0%A4%BE%E0%A4%AE%E0%A4%B0%E0%A4%BE%E0%A4%9C%E0%A5%8D%E0%A4%AF",
#     "promoted_content": null,
#     "query": "%23%E0%A4%AE%E0%A5%8B%E0%A4%A6%E0%A5%80_%E0%A4%95%E0%A4%BE_%E0%A4%B0%E0%A4%BE%E0%A4%AE%E0%A4%B0%E0%A4%BE%E0%A4%9C%E0%A5%8D%E0%A4%AF",
#     "tweet_volume": 77721
#    },
#    {
#     "name": "#\u062d\u0632\u0628_\u0627\u0644\u0628\u0646\u0641\u0633\u062c",
#     "url": "http://twitter.com/search?q=%23%D8%AD%D8%B2%D8%A8_%D8%A7%D9%84%D8%A8%D9%86%D9%81%D8%B3%D8%AC",
#     "promoted_content": null,
#     "query": "%23%D8%AD%D8%B2%D8%A8_%D8%A7%D9%84%D8%A8%D9%86%D9%81%D8%B3%D8%AC",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\u9ad8\u6a4b\u512a10\u5468\u5e74",
#     "url": "http://twitter.com/search?q=%23%E9%AB%98%E6%A9%8B%E5%84%AA10%E5%91%A8%E5%B9%B4",
#     "promoted_content": null,
#     "query": "%23%E9%AB%98%E6%A9%8B%E5%84%AA10%E5%91%A8%E5%B9%B4",
#     "tweet_volume": 24479
#    },
#    {
#     "name": "#FamiliasContraFelipeNeto",
#     "url": "http://twitter.com/search?q=%23FamiliasContraFelipeNeto",
#     "promoted_content": null,
#     "query": "%23FamiliasContraFelipeNeto",
#     "tweet_volume": null
#    },
#    {
#     "name": "#PECKXKAO",
#     "url": "http://twitter.com/search?q=%23PECKXKAO",
#     "promoted_content": null,
#     "query": "%23PECKXKAO",
#     "tweet_volume": 70551
#    },
#    {
#     "name": "#Reform\u0130craatDe\u011fi\u015fim",
#     "url": "http://twitter.com/search?q=%23Reform%C4%B0craatDe%C4%9Fi%C5%9Fim",
#     "promoted_content": null,
#     "query": "%23Reform%C4%B0craatDe%C4%9Fi%C5%9Fim",
#     "tweet_volume": 20227
#    },
#    {
#     "name": "#SIGNALforONCEtoVOTE",
#     "url": "http://twitter.com/search?q=%23SIGNALforONCEtoVOTE",
#     "promoted_content": null,
#     "query": "%23SIGNALforONCEtoVOTE",
#     "tweet_volume": 31653
#    },
#    {
#     "name": "#RussiaReport",
#     "url": "http://twitter.com/search?q=%23RussiaReport",
#     "promoted_content": null,
#     "query": "%23RussiaReport",
#     "tweet_volume": 117246
#    },
#    {
#     "name": "#OnePlusNord",
#     "url": "http://twitter.com/search?q=%23OnePlusNord",
#     "promoted_content": null,
#     "query": "%23OnePlusNord",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MOASelcaDay",
#     "url": "http://twitter.com/search?q=%23MOASelcaDay",
#     "promoted_content": null,
#     "query": "%23MOASelcaDay",
#     "tweet_volume": 52246
#    },
#    {
#     "name": "#SoniaJinRahulPing",
#     "url": "http://twitter.com/search?q=%23SoniaJinRahulPing",
#     "promoted_content": null,
#     "query": "%23SoniaJinRahulPing",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Thanks_to_CRAVITY",
#     "url": "http://twitter.com/search?q=%23Thanks_to_CRAVITY",
#     "promoted_content": null,
#     "query": "%23Thanks_to_CRAVITY",
#     "tweet_volume": 29306
#    },
#    {
#     "name": "#RobinWilliams",
#     "url": "http://twitter.com/search?q=%23RobinWilliams",
#     "promoted_content": null,
#     "query": "%23RobinWilliams",
#     "tweet_volume": 12448
#    },
#    {
#     "name": "#PrisaoPerpetuaPedofilia",
#     "url": "http://twitter.com/search?q=%23PrisaoPerpetuaPedofilia",
#     "promoted_content": null,
#     "query": "%23PrisaoPerpetuaPedofilia",
#     "tweet_volume": null
#    },
#    {
#     "name": "#BoycottMLB",
#     "url": "http://twitter.com/search?q=%23BoycottMLB",
#     "promoted_content": null,
#     "query": "%23BoycottMLB",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\uc544\ubbf8_\uc778\uae30\uc0c1_ON",
#     "url": "http://twitter.com/search?q=%23%EC%95%84%EB%AF%B8_%EC%9D%B8%EA%B8%B0%EC%83%81_ON",
#     "promoted_content": null,
#     "query": "%23%EC%95%84%EB%AF%B8_%EC%9D%B8%EA%B8%B0%EC%83%81_ON",
#     "tweet_volume": 37849
#    },
#    {
#     "name": "#50DaysToAKSHAYsBday",
#     "url": "http://twitter.com/search?q=%2350DaysToAKSHAYsBday",
#     "promoted_content": null,
#     "query": "%2350DaysToAKSHAYsBday",
#     "tweet_volume": 90372
#    },
#    {
#     "name": "#MartinPradenas",
#     "url": "http://twitter.com/search?q=%23MartinPradenas",
#     "promoted_content": null,
#     "query": "%23MartinPradenas",
#     "tweet_volume": null
#    },
#    {
#     "name": "#lovingwendyhours",
#     "url": "http://twitter.com/search?q=%23lovingwendyhours",
#     "promoted_content": null,
#     "query": "%23lovingwendyhours",
#     "tweet_volume": 26660
#    },
#    {
#     "name": "#GymKholoModiJi",
#     "url": "http://twitter.com/search?q=%23GymKholoModiJi",
#     "promoted_content": null,
#     "query": "%23GymKholoModiJi",
#     "tweet_volume": 27976
#    },
#    {
#     "name": "#Apple1stWin",
#     "url": "http://twitter.com/search?q=%23Apple1stWin",
#     "promoted_content": null,
#     "query": "%23Apple1stWin",
#     "tweet_volume": 53905
#    },
#    {
#     "name": "#LiveinconcertHolyTrinity",
#     "url": "http://twitter.com/search?q=%23LiveinconcertHolyTrinity",
#     "promoted_content": null,
#     "query": "%23LiveinconcertHolyTrinity",
#     "tweet_volume": null
#    },
#    {
#     "name": "#FraCasado",
#     "url": "http://twitter.com/search?q=%23FraCasado",
#     "promoted_content": null,
#     "query": "%23FraCasado",
#     "tweet_volume": 12126
#    },
#    {
#     "name": "#\ud65410\uc2dc_\ubb38\ubcc4\uc758_\uc5b4\ubca4\uac78\uc2a4",
#     "url": "http://twitter.com/search?q=%23%ED%99%9410%EC%8B%9C_%EB%AC%B8%EB%B3%84%EC%9D%98_%EC%96%B4%EB%B2%A4%EA%B1%B8%EC%8A%A4",
#     "promoted_content": null,
#     "query": "%23%ED%99%9410%EC%8B%9C_%EB%AC%B8%EB%B3%84%EC%9D%98_%EC%96%B4%EB%B2%A4%EA%B1%B8%EC%8A%A4",
#     "tweet_volume": 14072
#    },
#    {
#     "name": "#ColombiaFederalEs",
#     "url": "http://twitter.com/search?q=%23ColombiaFederalEs",
#     "promoted_content": null,
#     "query": "%23ColombiaFederalEs",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\u30b7\u30e3\u30c1ZERO",
#     "url": "http://twitter.com/search?q=%23%E3%82%B7%E3%83%A3%E3%83%81ZERO",
#     "promoted_content": null,
#     "query": "%23%E3%82%B7%E3%83%A3%E3%83%81ZERO",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2020-07-21T14:29:49Z",
#   "created_at": "2020-07-21T14:28:47Z",
#   "locations": [
#    {
#     "name": "Worldwide",
#     "woeid": 1
#    }
#   ]
#  }
# ]

# %%
# We can also get US trends without a problem
us_trends = twitter_api.trends.place(_id=US_WOEID)
print(json.dumps(us_trends, indent=1))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#tuesdayvibes",
#     "url": "http://twitter.com/search?q=%23tuesdayvibes",
#     "promoted_content": null,
#     "query": "%23tuesdayvibes",
#     "tweet_volume": 30912
#    },
#    {
#     "name": "#BoycottMLB",
#     "url": "http://twitter.com/search?q=%23BoycottMLB",
#     "promoted_content": null,
#     "query": "%23BoycottMLB",
#     "tweet_volume": null
#    },
#    {
#     "name": "#RobinWilliams",
#     "url": "http://twitter.com/search?q=%23RobinWilliams",
#     "promoted_content": null,
#     "query": "%23RobinWilliams",
#     "tweet_volume": 12127
#    },
#    {
#     "name": "#IfSchoolsReopenNow",
#     "url": "http://twitter.com/search?q=%23IfSchoolsReopenNow",
#     "promoted_content": null,
#     "query": "%23IfSchoolsReopenNow",
#     "tweet_volume": null
#    },
#    {
#     "name": "Larry Householder",
#     "url": "http://twitter.com/search?q=%22Larry+Householder%22",
#     "promoted_content": null,
#     "query": "%22Larry+Householder%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#NationalJunkFoodDay",
#     "url": "http://twitter.com/search?q=%23NationalJunkFoodDay",
#     "promoted_content": null,
#     "query": "%23NationalJunkFoodDay",
#     "tweet_volume": null
#    },
#    {
#     "name": "Tom Cotton",
#     "url": "http://twitter.com/search?q=%22Tom+Cotton%22",
#     "promoted_content": null,
#     "query": "%22Tom+Cotton%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Tucker",
#     "url": "http://twitter.com/search?q=Tucker",
#     "promoted_content": null,
#     "query": "Tucker",
#     "tweet_volume": 399496
#    },
#    {
#     "name": "Michael Bennett",
#     "url": "http://twitter.com/search?q=%22Michael+Bennett%22",
#     "promoted_content": null,
#     "query": "%22Michael+Bennett%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Natalie Portman",
#     "url": "http://twitter.com/search?q=%22Natalie+Portman%22",
#     "promoted_content": null,
#     "query": "%22Natalie+Portman%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Cat Stevens",
#     "url": "http://twitter.com/search?q=%22Cat+Stevens%22",
#     "promoted_content": null,
#     "query": "%22Cat+Stevens%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Ernest Hemingway",
#     "url": "http://twitter.com/search?q=%22Ernest+Hemingway%22",
#     "promoted_content": null,
#     "query": "%22Ernest+Hemingway%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Kneeling",
#     "url": "http://twitter.com/search?q=Kneeling",
#     "promoted_content": null,
#     "query": "Kneeling",
#     "tweet_volume": 63056
#    },
#    {
#     "name": "Kreayshawn",
#     "url": "http://twitter.com/search?q=Kreayshawn",
#     "promoted_content": null,
#     "query": "Kreayshawn",
#     "tweet_volume": 17677
#    },
#    {
#     "name": "Angel City",
#     "url": "http://twitter.com/search?q=%22Angel+City%22",
#     "promoted_content": null,
#     "query": "%22Angel+City%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Scott Pilgrim",
#     "url": "http://twitter.com/search?q=%22Scott+Pilgrim%22",
#     "promoted_content": null,
#     "query": "%22Scott+Pilgrim%22",
#     "tweet_volume": 21497
#    },
#    {
#     "name": "Text REGISTER to 644-33",
#     "url": "http://twitter.com/search?q=%22Text+REGISTER+to+644-33%22",
#     "promoted_content": null,
#     "query": "%22Text+REGISTER+to+644-33%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Gabe Kapler",
#     "url": "http://twitter.com/search?q=%22Gabe+Kapler%22",
#     "promoted_content": null,
#     "query": "%22Gabe+Kapler%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Carlson",
#     "url": "http://twitter.com/search?q=Carlson",
#     "promoted_content": null,
#     "query": "Carlson",
#     "tweet_volume": 263377
#    },
#    {
#     "name": "mad dog 2020",
#     "url": "http://twitter.com/search?q=%22mad+dog+2020%22",
#     "promoted_content": null,
#     "query": "%22mad+dog+2020%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "One Hour Photo",
#     "url": "http://twitter.com/search?q=%22One+Hour+Photo%22",
#     "promoted_content": null,
#     "query": "%22One+Hour+Photo%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "God and Father",
#     "url": "http://twitter.com/search?q=%22God+and+Father%22",
#     "promoted_content": null,
#     "query": "%22God+and+Father%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Mail-in",
#     "url": "http://twitter.com/search?q=Mail-in",
#     "promoted_content": null,
#     "query": "Mail-in",
#     "tweet_volume": 35615
#    },
#    {
#     "name": "NWSL",
#     "url": "http://twitter.com/search?q=NWSL",
#     "promoted_content": null,
#     "query": "NWSL",
#     "tweet_volume": null
#    },
#    {
#     "name": "Alyssa Nakken",
#     "url": "http://twitter.com/search?q=%22Alyssa+Nakken%22",
#     "promoted_content": null,
#     "query": "%22Alyssa+Nakken%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Dead Poets Society",
#     "url": "http://twitter.com/search?q=%22Dead+Poets+Society%22",
#     "promoted_content": null,
#     "query": "%22Dead+Poets+Society%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Alexios",
#     "url": "http://twitter.com/search?q=Alexios",
#     "promoted_content": null,
#     "query": "Alexios",
#     "tweet_volume": null
#    },
#    {
#     "name": "Good Morning Vietnam",
#     "url": "http://twitter.com/search?q=%22Good+Morning+Vietnam%22",
#     "promoted_content": null,
#     "query": "%22Good+Morning+Vietnam%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#RIGGEDELECTION",
#     "url": "http://twitter.com/search?q=%23RIGGEDELECTION",
#     "promoted_content": null,
#     "query": "%23RIGGEDELECTION",
#     "tweet_volume": 17368
#    },
#    {
#     "name": "#PrayForYe",
#     "url": "http://twitter.com/search?q=%23PrayForYe",
#     "promoted_content": null,
#     "query": "%23PrayForYe",
#     "tweet_volume": null
#    },
#    {
#     "name": "#NERevs",
#     "url": "http://twitter.com/search?q=%23NERevs",
#     "promoted_content": null,
#     "query": "%23NERevs",
#     "tweet_volume": null
#    },
#    {
#     "name": "#NPSDCHAT",
#     "url": "http://twitter.com/search?q=%23NPSDCHAT",
#     "promoted_content": null,
#     "query": "%23NPSDCHAT",
#     "tweet_volume": null
#    },
#    {
#     "name": "#NCEdEquity",
#     "url": "http://twitter.com/search?q=%23NCEdEquity",
#     "promoted_content": null,
#     "query": "%23NCEdEquity",
#     "tweet_volume": null
#    },
#    {
#     "name": "#iheartfestival",
#     "url": "http://twitter.com/search?q=%23iheartfestival",
#     "promoted_content": null,
#     "query": "%23iheartfestival",
#     "tweet_volume": 10059
#    },
#    {
#     "name": "#TrueToAtlanta",
#     "url": "http://twitter.com/search?q=%23TrueToAtlanta",
#     "promoted_content": null,
#     "query": "%23TrueToAtlanta",
#     "tweet_volume": null
#    },
#    {
#     "name": "#WeAreAngelCity",
#     "url": "http://twitter.com/search?q=%23WeAreAngelCity",
#     "promoted_content": null,
#     "query": "%23WeAreAngelCity",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TORvNE",
#     "url": "http://twitter.com/search?q=%23TORvNE",
#     "promoted_content": null,
#     "query": "%23TORvNE",
#     "tweet_volume": null
#    },
#    {
#     "name": "#NFLCvirtualsummit",
#     "url": "http://twitter.com/search?q=%23NFLCvirtualsummit",
#     "promoted_content": null,
#     "query": "%23NFLCvirtualsummit",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MorningJoe",
#     "url": "http://twitter.com/search?q=%23MorningJoe",
#     "promoted_content": null,
#     "query": "%23MorningJoe",
#     "tweet_volume": 13870
#    },
#    {
#     "name": "#FelizMartes",
#     "url": "http://twitter.com/search?q=%23FelizMartes",
#     "promoted_content": null,
#     "query": "%23FelizMartes",
#     "tweet_volume": 18325
#    },
#    {
#     "name": "#BbWorld20",
#     "url": "http://twitter.com/search?q=%23BbWorld20",
#     "promoted_content": null,
#     "query": "%23BbWorld20",
#     "tweet_volume": null
#    },
#    {
#     "name": "#BookBirthday",
#     "url": "http://twitter.com/search?q=%23BookBirthday",
#     "promoted_content": null,
#     "query": "%23BookBirthday",
#     "tweet_volume": null
#    },
#    {
#     "name": "#CVFutureReady",
#     "url": "http://twitter.com/search?q=%23CVFutureReady",
#     "promoted_content": null,
#     "query": "%23CVFutureReady",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TransformationTuesday",
#     "url": "http://twitter.com/search?q=%23TransformationTuesday",
#     "promoted_content": null,
#     "query": "%23TransformationTuesday",
#     "tweet_volume": null
#    },
#    {
#     "name": "#deeperwiththedolantwins",
#     "url": "http://twitter.com/search?q=%23deeperwiththedolantwins",
#     "promoted_content": null,
#     "query": "%23deeperwiththedolantwins",
#     "tweet_volume": null
#    },
#    {
#     "name": "#21Jul",
#     "url": "http://twitter.com/search?q=%2321Jul",
#     "promoted_content": null,
#     "query": "%2321Jul",
#     "tweet_volume": 28490
#    },
#    {
#     "name": "#trumpconspiracy",
#     "url": "http://twitter.com/search?q=%23trumpconspiracy",
#     "promoted_content": null,
#     "query": "%23trumpconspiracy",
#     "tweet_volume": 25927
#    },
#    {
#     "name": "#askelijah",
#     "url": "http://twitter.com/search?q=%23askelijah",
#     "promoted_content": null,
#     "query": "%23askelijah",
#     "tweet_volume": 16605
#    },
#    {
#     "name": "#RussiaReport",
#     "url": "http://twitter.com/search?q=%23RussiaReport",
#     "promoted_content": null,
#     "query": "%23RussiaReport",
#     "tweet_volume": 116456
#    },
#    {
#     "name": "#OnePlusNord",
#     "url": "http://twitter.com/search?q=%23OnePlusNord",
#     "promoted_content": null,
#     "query": "%23OnePlusNord",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2020-07-21T14:29:44Z",
#   "created_at": "2020-07-21T14:23:46Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %%
# # We get a 404 error when we try to get UG trends
# ug_trends = twitter_api.trends.place(_id=UG_WOEID)
# print(json.dumps(ug_trends, indent=1))

# %%
# # We get the same 404 error for KLA
# kla_trends = twitter_api.trends.place(_id=KLA_WOEID)
# print(json.dumps(kla_trends, indent=1))

# %% [markdown]
# We get a 404 error when we use the WOEIDs for Kampala and Uganda. I've commented out the code for this because the response from twitter includes the API keys. You can clone this project and run this notebook to see the error.
#
# Here's the response:
# ```
# TwitterHTTPError: Twitter sent status 404 for URL: 1.1/trends/place.json using parameters: (id=1451962)
# details: {'errors': [{'code': 34, 'message': 'Sorry, that page does not exist.'}]}
# ```

# %%
# However we can get bKenya trends without a problem
kenya_trends = twitter_api.trends.place(_id=KENYA_WOEID)
print(json.dumps(kenya_trends, indent=1))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#njoro",
#     "url": "http://twitter.com/search?q=%23njoro",
#     "promoted_content": null,
#     "query": "%23njoro",
#     "tweet_volume": null
#    },
#    {
#     "name": "Churchill",
#     "url": "http://twitter.com/search?q=Churchill",
#     "promoted_content": null,
#     "query": "Churchill",
#     "tweet_volume": 13505
#    },
#    {
#     "name": "#testingtuesday",
#     "url": "http://twitter.com/search?q=%23testingtuesday",
#     "promoted_content": null,
#     "query": "%23testingtuesday",
#     "tweet_volume": null
#    },
#    {
#     "name": "#KibosLordsOfImpunity",
#     "url": "http://twitter.com/search?q=%23KibosLordsOfImpunity",
#     "promoted_content": null,
#     "query": "%23KibosLordsOfImpunity",
#     "tweet_volume": null
#    },
#    {
#     "name": "#SakajaCharged",
#     "url": "http://twitter.com/search?q=%23SakajaCharged",
#     "promoted_content": null,
#     "query": "%23SakajaCharged",
#     "tweet_volume": null
#    },
#    {
#     "name": "Watford",
#     "url": "http://twitter.com/search?q=Watford",
#     "promoted_content": null,
#     "query": "Watford",
#     "tweet_volume": 10618
#    },
#    {
#     "name": "#Hot96Drive",
#     "url": "http://twitter.com/search?q=%23Hot96Drive",
#     "promoted_content": null,
#     "query": "%23Hot96Drive",
#     "tweet_volume": null
#    },
#    {
#     "name": "Aoko",
#     "url": "http://twitter.com/search?q=Aoko",
#     "promoted_content": null,
#     "query": "Aoko",
#     "tweet_volume": null
#    },
#    {
#     "name": "Drake",
#     "url": "http://twitter.com/search?q=Drake",
#     "promoted_content": null,
#     "query": "Drake",
#     "tweet_volume": 266402
#    },
#    {
#     "name": "jeff",
#     "url": "http://twitter.com/search?q=jeff",
#     "promoted_content": null,
#     "query": "jeff",
#     "tweet_volume": 103474
#    },
#    {
#     "name": "Karen Hospital",
#     "url": "http://twitter.com/search?q=%22Karen+Hospital%22",
#     "promoted_content": null,
#     "query": "%22Karen+Hospital%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "nairobi senator johnson sakaja",
#     "url": "http://twitter.com/search?q=%22nairobi+senator+johnson+sakaja%22",
#     "promoted_content": null,
#     "query": "%22nairobi+senator+johnson+sakaja%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "senior counsel",
#     "url": "http://twitter.com/search?q=%22senior+counsel%22",
#     "promoted_content": null,
#     "query": "%22senior+counsel%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "nicki",
#     "url": "http://twitter.com/search?q=nicki",
#     "promoted_content": null,
#     "query": "nicki",
#     "tweet_volume": 767525
#    },
#    {
#     "name": "congratulations sc",
#     "url": "http://twitter.com/search?q=%22congratulations+sc%22",
#     "promoted_content": null,
#     "query": "%22congratulations+sc%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "De Gea",
#     "url": "http://twitter.com/search?q=%22De+Gea%22",
#     "promoted_content": null,
#     "query": "%22De+Gea%22",
#     "tweet_volume": 27014
#    },
#    {
#     "name": "Covid",
#     "url": "http://twitter.com/search?q=Covid",
#     "promoted_content": null,
#     "query": "Covid",
#     "tweet_volume": 2594839
#    },
#    {
#     "name": "Magufuli",
#     "url": "http://twitter.com/search?q=Magufuli",
#     "promoted_content": null,
#     "query": "Magufuli",
#     "tweet_volume": null
#    },
#    {
#     "name": "JUNET",
#     "url": "http://twitter.com/search?q=JUNET",
#     "promoted_content": null,
#     "query": "JUNET",
#     "tweet_volume": null
#    },
#    {
#     "name": "Lewandowski",
#     "url": "http://twitter.com/search?q=Lewandowski",
#     "promoted_content": null,
#     "query": "Lewandowski",
#     "tweet_volume": 37828
#    },
#    {
#     "name": "mike sonko",
#     "url": "http://twitter.com/search?q=%22mike+sonko%22",
#     "promoted_content": null,
#     "query": "%22mike+sonko%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Lucy",
#     "url": "http://twitter.com/search?q=Lucy",
#     "promoted_content": null,
#     "query": "Lucy",
#     "tweet_volume": 53776
#    },
#    {
#     "name": "kalonzo musyoka",
#     "url": "http://twitter.com/search?q=%22kalonzo+musyoka%22",
#     "promoted_content": null,
#     "query": "%22kalonzo+musyoka%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#BillyNaMbaruk",
#     "url": "http://twitter.com/search?q=%23BillyNaMbaruk",
#     "promoted_content": null,
#     "query": "%23BillyNaMbaruk",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TuesdayMotivation",
#     "url": "http://twitter.com/search?q=%23TuesdayMotivation",
#     "promoted_content": null,
#     "query": "%23TuesdayMotivation",
#     "tweet_volume": 28547
#    },
#    {
#     "name": "#NewLordOfPoverty",
#     "url": "http://twitter.com/search?q=%23NewLordOfPoverty",
#     "promoted_content": null,
#     "query": "%23NewLordOfPoverty",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Nairobi",
#     "url": "http://twitter.com/search?q=%23Nairobi",
#     "promoted_content": null,
#     "query": "%23Nairobi",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MainaAndKingangi",
#     "url": "http://twitter.com/search?q=%23MainaAndKingangi",
#     "promoted_content": null,
#     "query": "%23MainaAndKingangi",
#     "tweet_volume": null
#    },
#    {
#     "name": "#KameneAndJalas",
#     "url": "http://twitter.com/search?q=%23KameneAndJalas",
#     "promoted_content": null,
#     "query": "%23KameneAndJalas",
#     "tweet_volume": null
#    },
#    {
#     "name": "#flattenthecurve",
#     "url": "http://twitter.com/search?q=%23flattenthecurve",
#     "promoted_content": null,
#     "query": "%23flattenthecurve",
#     "tweet_volume": null
#    },
#    {
#     "name": "#mondaymotivation",
#     "url": "http://twitter.com/search?q=%23mondaymotivation",
#     "promoted_content": null,
#     "query": "%23mondaymotivation",
#     "tweet_volume": 79058
#    },
#    {
#     "name": "#barakazamilele",
#     "url": "http://twitter.com/search?q=%23barakazamilele",
#     "promoted_content": null,
#     "query": "%23barakazamilele",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MikeSonkoScoreCard",
#     "url": "http://twitter.com/search?q=%23MikeSonkoScoreCard",
#     "promoted_content": null,
#     "query": "%23MikeSonkoScoreCard",
#     "tweet_volume": null
#    },
#    {
#     "name": "#sakajaapologises",
#     "url": "http://twitter.com/search?q=%23sakajaapologises",
#     "promoted_content": null,
#     "query": "%23sakajaapologises",
#     "tweet_volume": null
#    },
#    {
#     "name": "#BBNaija",
#     "url": "http://twitter.com/search?q=%23BBNaija",
#     "promoted_content": null,
#     "query": "%23BBNaija",
#     "tweet_volume": 101515
#    },
#    {
#     "name": "#wakstikitaka",
#     "url": "http://twitter.com/search?q=%23wakstikitaka",
#     "promoted_content": null,
#     "query": "%23wakstikitaka",
#     "tweet_volume": null
#    },
#    {
#     "name": "#niokoenikuokoe",
#     "url": "http://twitter.com/search?q=%23niokoenikuokoe",
#     "promoted_content": null,
#     "query": "%23niokoenikuokoe",
#     "tweet_volume": null
#    },
#    {
#     "name": "#EngageTheIG",
#     "url": "http://twitter.com/search?q=%23EngageTheIG",
#     "promoted_content": null,
#     "query": "%23EngageTheIG",
#     "tweet_volume": null
#    },
#    {
#     "name": "#alexnatricky",
#     "url": "http://twitter.com/search?q=%23alexnatricky",
#     "promoted_content": null,
#     "query": "%23alexnatricky",
#     "tweet_volume": null
#    },
#    {
#     "name": "#natafutakazi",
#     "url": "http://twitter.com/search?q=%23natafutakazi",
#     "promoted_content": null,
#     "query": "%23natafutakazi",
#     "tweet_volume": null
#    },
#    {
#     "name": "#brekko",
#     "url": "http://twitter.com/search?q=%23brekko",
#     "promoted_content": null,
#     "query": "%23brekko",
#     "tweet_volume": null
#    },
#    {
#     "name": "#thehotbreakfast",
#     "url": "http://twitter.com/search?q=%23thehotbreakfast",
#     "promoted_content": null,
#     "query": "%23thehotbreakfast",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MixedFlavors",
#     "url": "http://twitter.com/search?q=%23MixedFlavors",
#     "promoted_content": null,
#     "query": "%23MixedFlavors",
#     "tweet_volume": null
#    },
#    {
#     "name": "#jambokenya",
#     "url": "http://twitter.com/search?q=%23jambokenya",
#     "promoted_content": null,
#     "query": "%23jambokenya",
#     "tweet_volume": null
#    },
#    {
#     "name": "#pearlinthemorning",
#     "url": "http://twitter.com/search?q=%23pearlinthemorning",
#     "promoted_content": null,
#     "query": "%23pearlinthemorning",
#     "tweet_volume": null
#    },
#    {
#     "name": "#aminaforwto",
#     "url": "http://twitter.com/search?q=%23aminaforwto",
#     "promoted_content": null,
#     "query": "%23aminaforwto",
#     "tweet_volume": null
#    },
#    {
#     "name": "#gmitm",
#     "url": "http://twitter.com/search?q=%23gmitm",
#     "promoted_content": null,
#     "query": "%23gmitm",
#     "tweet_volume": null
#    },
#    {
#     "name": "#AminaandFareed",
#     "url": "http://twitter.com/search?q=%23AminaandFareed",
#     "promoted_content": null,
#     "query": "%23AminaandFareed",
#     "tweet_volume": null
#    },
#    {
#     "name": "#rippapashirandula",
#     "url": "http://twitter.com/search?q=%23rippapashirandula",
#     "promoted_content": null,
#     "query": "%23rippapashirandula",
#     "tweet_volume": null
#    },
#    {
#     "name": "#safarinandiema",
#     "url": "http://twitter.com/search?q=%23safarinandiema",
#     "promoted_content": null,
#     "query": "%23safarinandiema",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2020-07-21T14:30:09Z",
#   "created_at": "2020-07-21T14:28:48Z",
#   "locations": [
#    {
#     "name": "Kenya",
#     "woeid": 23424863
#    }
#   ]
#  }
# ]

# %% [markdown]
# We can try to use the `twitter_api.trends.available()` to find the locations which are supported by Twitter.

# %%
# Get available locations for trends
available_locations = twitter_api.trends.available()
print("Number of locations available: {}", len(available_locations))
print(json.dumps(available_locations[0], indent=1))
# Out:
# Number of locations available: {} 467
# {
#  "name": "Worldwide",
#  "placeType": {
#   "code": 19,
#   "name": "Supername"
#  },
#  "url": "http://where.yahooapis.com/v1/place/1",
#  "parentid": 0,
#  "country": "",
#  "woeid": 1,
#  "countryCode": null
# }

# %%
# Trying to find out if Uganda or Kampala is in this list
for location in available_locations:
    if location['name'] == 'Uganda' or location['name'] == 'Kampala':
        print("Found Uganda or Kampala")
        print(json.dumps(location, indent=1))

# Nothing found :(
